# %%
import ParetoCheck as PC
import config
import time
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import random
import multiprocessing
import main_py_fun_ws_OLTC as mfws
import numpy as np


print(abs(-1))
# Out:
# 1

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import config
import os
import time

obj = 4
P_pv_max = 10/100
N_random = 30
w = np.load('random_ws_wc_OLTC_'+str(N_random)+'_'+str(1)+'.npy')
for batch in range(2,3):
    ww = np.load('random_ws_wc_OLTC_'+str(N_random)+'_'+str(batch)+'.npy')
    w = np.vstack((w,ww))

for w_term in w:
    path = './DataFile/'
    result_data = np.load(path + 'result_obj'+str(obj)+'_w1_'+str(round(w_term[0],8))+'_w2_'+str(round(w_term[1],8))+'_pv'+str(P_pv_max)+'.npz')
    pv_cap = result_data['pv_cap']
    E_ess = result_data['E_ess']
    p_ess = result_data['p_ess']
    print('PV unit capacity: ', pv_cap)
    print('ESS energy capacity: ', E_ess)
    print('ESS power capacity: ', p_ess)
# Out:
# PV unit capacity:  [[3.21593506e-07]
#  [1.40211225e-02]
#  [1.67142408e-06]
#  [3.41281674e-06]
#  [7.28620656e-07]
#  [5.64760792e-07]
#  [3.97295265e-02]
#  [2.96510131e-04]
#  [1.53210003e-06]
#  [6.17609895e-07]]
# ESS energy capacity:  [[0.04999995]
#  [0.04999992]
#  [0.04999984]
#  [0.04999996]
#  [0.04999993]]
# ESS power capacity:  [[0.02485074]
#  [0.02222245]
#  [0.02222166]
#  [0.03611889]
#  [0.04635792]]
# PV unit capacity:  [[1.08187481e-06]
#  [1.49066217e-02]
#  [1.51648253e-05]
#  [7.53947781e-04]
#  [1.74019177e-06]
#  [5.04182267e-06]
#  [1.28669450e-02]
#  [1.71930686e-02]
#  [2.15621326e-02]
#  [1.18322489e-04]]
# ESS energy capacity:  [[0.00463177]
#  [0.01717323]
#  [0.00748106]
#  [0.01080573]
#  [0.01981929]]
# ESS power capacity:  [[0.00463173]
#  [0.01717322]
#  [0.00538634]
#  [0.00960577]
#  [0.01981926]]
# PV unit capacity:  [[1.21514197e-06]
#  [1.47880595e-02]
#  [2.76950741e-06]
#  [3.73134102e-04]
#  [1.87809586e-06]
#  [3.31131034e-06]
# ...

# %%
import numpy as np
import scipy.io

end_bus = scipy.io.loadmat('end_bus.mat')['end_bus'] 

if 6 in end_bus:
    print('yes')
# Out:
# yes
